# %%
# !pip install -q uv
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.1/20.1 MB 18.7 MB/s eta 0:00:00

# %%
# !uv python install 3.11
# Out:
# Installed Python 3.11.16 in 2.22s
#  + cpython-3.11.16-linux-x86_64-gnu (python3.11)
# ...

# %%
# !uv venv --python 3.11 /content/pycaret-env
# Out:
# ...
# Using CPython 3.11.16
# Creating virtual environment at: pycaret-env
# Activate with: source pycaret-env/bin/activate

# %%
# !uv pip install --python /content/pycaret-env/bin/python "pycaret==3.3.2"
# Out:
# Using Python 3.11.16 environment at: pycaret-env
# Resolved 106 packages in 1.18s
# Prepared 106 packages in 9.02s
# Installed 106 packages in 1.18s
#  + annotated-types==0.8.0
#  + asttokens==3.0.2
#  + attrs==26.1.0
#  + blinker==1.9.0
#  + category-encoders==2.7.0
#  + certifi==2026.7.22
#  + charset-normalizer==3.5.1
#  + choreographer==1.4.0
#  + click==8.5.0
#  + cloudpickle==3.1.2
#  + comm==0.2.3
#  + contourpy==1.3.3
#  + cycler==0.12.1
#  + cython==3.3.0
#  + dash==4.4.1
#  + deprecation==2.1.0
#  + executing==2.2.1
#  + fastjsonschema==2.22.2
#  + flask==3.1.3
#  + fonttools==4.65.0
#  + formulaic==1.2.2
#  + idna==3.20
#  + imbalanced-learn==0.14.2
#  + importlib-metadata==9.0.1
#  + interface-meta==2.0.1
#  + ipython==9.17.1
#  + ipython-pygments-lexers==1.1.1
#  + ipywidgets==8.1.9
#  + itsdangerous==2.2.0
#  + janus==2.0.0
#  + jedi==0.20.0
#  + jinja2==3.1.6
#  + joblib==1.3.2
#  + jsonschema==4.26.0
#  + jsonschema-specifications==2025.9.1
#  + jupyter-core==5.9.1
# ...

# %%
# !/content/pycaret-env/bin/python -c "import pycaret; print(pycaret.__version__)"
# Out:
# 3.3.2

# %%
# %%writefile /content/example3.27.py

import pandas as pd
from sklearn import datasets

iris = datasets.load_iris(as_frame=True)
iris.data['Target'] = iris.target
iris = iris.data

print(iris.head())

from pycaret import classification

classification.setup(data=iris, target='Target')
classification.compare_models()
# Out:
# Writing /content/example3.27.py

# %%
# !/content/pycaret-env/bin/python /content/example3.27.py
# Out:
#    sepal length (cm)  sepal width (cm)  ...  petal width (cm)  Target
# 0                5.1               3.5  ...               0.2       0
# 1                4.9               3.0  ...               0.2       0
# 2                4.7               3.2  ...               0.2       0
# 3                4.6               3.1  ...               0.2       0
# 4                5.0               3.6  ...               0.2       0
#
# [5 rows x 5 columns]
#                     Description             Value
# 0                    Session id              8994
# 1                        Target            Target
# 2                   Target type        Multiclass
# 3           Original data shape          (150, 5)
# 4        Transformed data shape          (150, 5)
# 5   Transformed train set shape          (105, 5)
# 6    Transformed test set shape           (45, 5)
# 7              Numeric features                 4
# 8                    Preprocess              True
# ...

# %%
# %%writefile /content/exercise3.19.py

from sklearn.datasets import load_breast_cancer

cancer = load_breast_cancer(as_frame=True)

data = cancer.data
data['Target'] = cancer.target

print(data.head())

from pycaret import classification

classification.setup(data=data, target='Target')
classification.compare_models()
# Out:
# Writing /content/exercise3.19.py

# %%
# !/content/pycaret-env/bin/python /content/exercise3.19.py
# Out:
#    mean radius  mean texture  ...  worst fractal dimension  Target
# 0        17.99         10.38  ...                  0.11890       0
# 1        20.57         17.77  ...                  0.08902       0
# 2        19.69         21.25  ...                  0.08758       0
# 3        11.42         20.38  ...                  0.17300       0
# 4        20.29         14.34  ...                  0.07678       0
#
# [5 rows x 31 columns]
#                     Description             Value
# 0                    Session id              3356
# 1                        Target            Target
# 2                   Target type            Binary
# 3           Original data shape         (569, 31)
# 4        Transformed data shape         (569, 31)
# 5   Transformed train set shape         (398, 31)
# 6    Transformed test set shape         (171, 31)
# 7              Numeric features                30
# 8                    Preprocess              True
# ...

# %%
# !pip install -q -U lazypredict
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.0/71.0 kB 3.2 MB/s eta 0:00:00

# %%
from lazypredict.Supervised import LazyClassifier, LazyRegressor

print("LazyPredict BERHASIL")
# Out:
# LazyPredict BERHASIL

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split

X, y = load_iris(return_X_y=True)

X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=.25,
    random_state=1
)

clf = LazyClassifier()

models, predictions = clf.fit(
    X_train,
    X_test,
    y_train,
    y_test
)

print(models)
# Out:
#                                Accuracy  Balanced Accuracy   ROC AUC  \
# Model
# LabelPropagation               1.000000           1.000000  1.000000
# LinearDiscriminantAnalysis     1.000000           1.000000  1.000000
# LabelSpreading                 1.000000           1.000000  1.000000
# QuadraticDiscriminantAnalysis  1.000000           1.000000  1.000000
# GaussianNB                     0.973684           0.979167  1.000000
# ExtraTreesClassifier           0.973684           0.979167  1.000000
# ExtraTreeClassifier            0.973684           0.979167  0.982759
# KNeighborsClassifier           0.973684           0.979167  0.998948
# DecisionTreeClassifier         0.973684           0.979167  0.982759
# BaggingClassifier              0.973684           0.979167  1.000000
# AdaBoostClassifier             0.973684           0.979167  0.973932
# SVC                            0.973684           0.979167       NaN
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.plot(models.index, models['Accuracy'], '-s')

plt.xticks(rotation=90)
plt.xlabel('Models')
plt.ylabel('Accuracy')
plt.title('Accuracy of Different Models')
plt.grid()
plt.show()

# %%
from lazypredict.Supervised import LazyRegressor

reg = LazyRegressor()

models, predictions = reg.fit(
    X_train,
    X_test,
    y_train,
    y_test
)

print(models)
# Out:
#                                Adjusted R-Squared  R-Squared      RMSE  \
# Model
# ExtraTreesRegressor                      0.974826   0.977548  0.112916
# KNeighborsRegressor                      0.960511   0.964780  0.141421
# BaggingRegressor                         0.957914   0.962463  0.145999
# RandomForestRegressor                    0.955861   0.960633  0.149517
# MLPRegressor                             0.955247   0.960085  0.150553
# GradientBoostingRegressor                0.950679   0.956011  0.158050
# AdaBoostRegressor                        0.948790   0.954326  0.161049
# ExtraTreeRegressor                       0.948041   0.953659  0.162221
# DecisionTreeRegressor                    0.948041   0.953659  0.162221
# SVR                                      0.941603   0.947916  0.171978
# HistGradientBoostingRegressor            0.941178   0.947537  0.172603
# LGBMRegressor                            0.932222   0.939549  0.185278
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.plot(models.index, models['R-Squared'], '-s')

plt.xticks(rotation=90)
plt.xlabel('Models')
plt.ylabel('R-Squared')
plt.title('R-Squared of Different Models')
plt.grid()
plt.show()

# %%
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split

X, y = load_breast_cancer(return_X_y=True)

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=.25,
    random_state=1
)

# %%
from lazypredict.Supervised import LazyClassifier

clf = LazyClassifier()

models, predictions = clf.fit(
    X_train,
    X_test,
    y_train,
    y_test
)

print(models)
# Out:
#                                Accuracy  Balanced Accuracy   ROC AUC  \
# Model
# LogisticRegression             0.979021           0.976136  0.995455
# LinearSVC                      0.965035           0.964773  0.992769
# AdaBoostClassifier             0.965035           0.961364  0.992975
# LGBMClassifier                 0.965035           0.961364  0.987397
# PassiveAggressiveClassifier    0.965035           0.961364  0.993388
# SVC                            0.965035           0.961364  0.995868
# QuadraticDiscriminantAnalysis  0.965035           0.957955  0.992975
# DecisionTreeClassifier         0.965035           0.957955  0.957955
# XGBClassifier                  0.958042           0.952273  0.988430
# CalibratedClassifierCV         0.958042           0.952273  0.995041
# Perceptron                     0.958042           0.948864  0.996074
# SGDClassifier                  0.958042           0.948864  0.994628
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
plt.plot(models.index, models['Accuracy'], '-s')

plt.xticks(rotation=90)
plt.xlabel('Models')
plt.ylabel('Accuracy')
plt.title('Accuracy of Different Models - Breast Cancer')
plt.grid()

plt.show()

# %%
from sklearn.datasets import load_diabetes
from sklearn.model_selection import train_test_split

X, y = load_diabetes(return_X_y=True)

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=.1,
    random_state=1
)

# %%
from lazypredict.Supervised import LazyRegressor

reg = LazyRegressor()

models, predictions = reg.fit(
    X_train,
    X_test,
    y_train,
    y_test
)

print(models)
# Out:
#                                Adjusted R-Squared  R-Squared        RMSE  \
# Model
# PassiveAggressiveRegressor               0.151031   0.343979   56.487839
# LinearRegression                         0.116748   0.317487   57.617111
# TransformedTargetRegressor               0.116748   0.317487   57.617111
# ElasticNet                               0.115076   0.316195   57.671616
# Ridge                                    0.114627   0.315848   57.686252
# ElasticNetCV                             0.113984   0.315351   57.707199
# HuberRegressor                           0.112070   0.313872   57.769479
# BayesianRidge                            0.112055   0.313861   57.769958
# RidgeCV                                  0.111446   0.313390   57.789789
# LassoLarsCV                              0.104312   0.307877   58.021316
# LassoCV                                  0.104179   0.307774   58.025624
# SGDRegressor                             0.103815   0.307493   58.037411
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
plt.plot(models.index, models['R-Squared'], '-s')

plt.xticks(rotation=90)
plt.xlabel('Models')
plt.ylabel('R-Squared')
plt.title('R-Squared of Different Models - Diabetes')
plt.grid()

plt.show()
